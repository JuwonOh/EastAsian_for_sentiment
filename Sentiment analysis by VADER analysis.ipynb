# %%
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## Lexicon and dcitionary-based sentiment analysis
#
# - VADER belongs to a type of sentiment analysis that is based on lexicons of sentiment-related words. VADER’s lexicon, where more positive words have higher positive ratings and more negative words have lower negative ratings.
#
# - https://github.com/cjhutto/vaderSentiment
# - https://pythonprogramming.net/sentiment-analysis-python-textblob-vader/
# - http://t-redactyl.io/blog/2017/04/using-vader-to-handle-sentiment-analysis-with-social-media-text.html
#
# ### Meaning of the compound score
#
#  - The VADER algorithm outputs sentiment scores to 4 classes of sentiments
#  - the compound score is a normalized score of sum_s.
#  - sum_s is the sum of valence computed based on some heuristics and a sentiment lexicon (aka. Sentiment Intensity)
#  and
# the normalized score is simply the sum_s divided by its square plus an alpha parameter that increases the denominator of the normalization function.
# https://stackoverflow.com/questions/40325980/how-is-the-vader-compound-polarity-score-calculated-in-python-nltk

# %%
## import vader analyser
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
## data import
wp = pd.read_csv('wp_all_sentence.csv', encoding = "cp949")
nyt = pd.read_csv('nyt_all_sentence.csv', encoding = "cp949")
wsj = pd.read_csv('wsj_all_sentence.csv', encoding = "cp949")
fox = pd.read_csv('fox_all_sentence.csv', encoding = "cp949")
cnn = pd.read_csv('cnn_all_sentence.csv', encoding = "cp949")

# %% [markdown]
# ### Making sentiment dataframe

# %%
def week_df(df, start_week, end_week):
    
    temp = df[(df.week >= start_week) & (df.week <= end_week)]
    if 'content' not in df:
        temp = temp.reset_index().iloc[:,2:8]
        # apply sentiment anlysis
        sentiment_list = []
        sentiment_list = [analyser.polarity_scores(x) for x in temp['title']]
        result = pd.concat([temp, pd.DataFrame(sentiment_list)], axis=1)
    
        # to avoid confusing to compound function in python
        result.columns = ['id', 'date', 'title', 'week', 'nation', "com", 'neg', 'neu', 'pos']
        # remove neutral variables
        result = result[(result.com >= 0.05) | (result.com <= -0.05)] 
        
    else:
        temp = temp.reset_index().iloc[:,2:9]
        # apply sentiment anlysis
        sentiment_list = []
        sentiment_list = [analyser.polarity_scores(x) for x in temp['content']]
        result = pd.concat([temp, pd.DataFrame(sentiment_list)], axis=1)
    
        # to avoid confusing to compound function in python
        result.columns = ['id', 'tot', 'date', 'title', 'content', 'nation', 'week', "com", 'neg', 'neu', 'pos']
        # remove meutral variables
        result = result[(result.com >= 0.05) | (result.com <= -0.05)] 
    
    return result

# %%
def sentiment_matrix(df, start_week, end_week):
    
    a = df[(df.week >= start_week) & (df.week <= end_week)].week.unique()
    mean_list =[]
    china_list = []
    nk_list = []
    sk_list = []
    japan_list =[]
    sam_list = []
    for week in a:
        temp = week_df(df, week, week)
        mean_list.append(temp.com.mean())
        china_list.append(temp[temp.nation == "c"].com.mean())
        nk_list.append(temp[temp.nation == "n"].com.mean())
        sk_list.append(temp[temp.nation == "k"].com.mean())
        japan_list.append(temp[temp.nation == "j"].com.mean())
        sam_list.append(np.unique(temp.nation, return_counts=True))
        
    sentiment_df = pd.DataFrame(list(zip(china_list, nk_list, sk_list, japan_list, sam_list)), 
                                columns =['china', 'nk', 'sk', 'japan', 'sample_size'], index=[a]) 
    return sentiment_df

# %%
fox_sent = sentiment_matrix(fox, 1, 35)
wp_sent = sentiment_matrix(wp, 1, 35)
nyt_sent = sentiment_matrix(nyt, 1, 35)
wsj_sent = sentiment_matrix(wsj, 1, 35)
cnn_sent = sentiment_matrix(cnn, 1, 35)

# %%
wp_sent
# Out:
#        china        nk        sk     japan  \
# 1   0.017264 -0.053033  0.286174  0.058800
# 2  -0.026665  0.239573  0.064025  0.078694
# 3  -0.086068  0.038648  0.003340 -0.009879
# 4   0.016686  0.130560  0.062159  0.068793
# 5   0.135900  0.012778  0.114928 -0.004344
# 6   0.047897  0.054068 -0.088922 -0.001216
# 7   0.008156 -0.201121  0.230665 -0.017127
# 8   0.114615  0.052027 -0.049841  0.001425
# 9   0.045205  0.027303  0.052661 -0.097723
# 10 -0.005680  0.009224  0.121700  0.042144
# 11  0.030468 -0.171127 -0.024906  0.170642
# 12  0.108448 -0.009628 -0.044174  0.092932
# 13 -0.008353 -0.145569  0.220305  0.199167
# 14 -0.007828 -0.406982  0.055644  0.109472
# 15  0.000214  0.250675  0.207548 -0.223259
# 16 -0.034282 -0.070069 -0.019739 -0.032127
# 17  0.102038  0.080802  0.319779  0.058373
# 18  0.033127 -0.117349 -0.067578  0.063215
# 19  0.044017 -0.100927 -0.083849  0.004151
# 20 -0.010048  0.020989 -0.180978 -0.114307
# 21 -0.020417 -0.127805 -0.084814  0.211861
# 22 -0.029262 -0.104796  0.188649 -0.164767
# 23 -0.019654 -0.209748  0.085566 -0.057943
# 24 -0.061795  0.001878 -0.027528 -0.104275
# 25  0.036262 -0.106101  0.195600 -0.002358
# 26  0.069435  0.093908  0.188624  0.067007
# 27 -0.022021  0.078133  0.413718  0.038152
# 28 -0.046521  0.047133 -0.231906 -0.011007
# 29 -0.060849 -0.258929 -0.101033  0.017036
# 30 -0.062225 -0.132377 -0.325555 -0.108283
# 31 -0.019186 -0.148158  0.011170 -0.219956
# 32 -0.130216 -0.018044 -0.128589 -0.272974
# 33 -0.123569 -0.084294 -0.101622  0.159438
# 34 -0.109654 -0.039888  0.004567  0.230762
# 35 -0.107780 -0.056125  0.061183  0.228903
#
#                              sample_size
# 1     ([c, j, k, n], [556, 28, 42, 101])
# 2      ([c, j, k, n], [275, 36, 24, 15])
# 3      ([c, j, k, n], [401, 39, 35, 97])
# 4      ([c, j, k, n], [354, 76, 39, 30])
# 5      ([c, j, k, n], [393, 32, 43, 97])
# 6      ([c, j, k, n], [253, 32, 27, 60])
# 7      ([c, j, k, n], [376, 56, 40, 47])
# 8    ([c, j, k, n], [369, 40, 101, 362])
# 9    ([c, j, k, n], [490, 31, 135, 716])
# 10    ([c, j, k, n], [365, 34, 24, 121])
# 11     ([c, j, k, n], [287, 33, 17, 45])
# 12     ([c, j, k, n], [342, 22, 43, 72])
# 13     ([c, j, k, n], [329, 42, 22, 67])
# 14      ([c, j, k, n], [375, 69, 9, 28])
# 15     ([c, j, k, n], [249, 78, 64, 56])
# 16    ([c, j, k, n], [178, 55, 23, 111])
# 17   ([c, j, k, n], [382, 103, 33, 179])
# 18     ([c, j, k, n], [581, 68, 50, 92])
# 19   ([c, j, k, n], [1171, 43, 63, 132])
# 20      ([c, j, k, n], [786, 43, 9, 54])
# 21     ([c, j, k, n], [440, 320, 7, 98])
# 22    ([c, j, k, n], [542, 183, 41, 97])
# 23     ([c, j, k, n], [651, 68, 32, 58])
# 24    ([c, j, k, n], [986, 102, 25, 88])
# 25     ([c, j, k, n], [586, 24, 11, 67])
# 26  ([c, j, k, n], [759, 160, 148, 317])
# 27     ([c, j, k, n], [293, 54, 11, 91])
# 28     ([c, j, k, n], [385, 27, 17, 18])
# 29     ([c, j, k, n], [329, 39, 21, 17])
# 30     ([c, j, k, n], [317, 23, 97, 53])
# 31     ([c, j, k, n], [501, 16, 43, 53])
# 32     ([c, j, k, n], [346, 34, 37, 52])
# 33     ([c, j, k, n], [836, 13, 27, 17])
# 34     ([c, j, k, n], [791, 42, 27, 17])
# 35     ([c, j, k, n], [518, 36, 12, 20])

# %%
fox_df = week_df(fox, 1, 35)
wp_df = week_df(wp, 1, 35)
nyt_df = week_df(nyt, 1, 35)
wsj_df = week_df(wsj, 1, 35)
cnn_df = week_df(cnn, 1, 35)

# %%
fox_df
# Out:
#          id       tot        date  \
# 0       315   315.150  2019-01-02
# 1       315   315.160  2019-01-02
# 3       316   316.900  2019-01-02
# 4       316   316.100  2019-01-02
# 5       316   316.370  2019-01-02
# 6       316   316.420  2019-01-02
# 7       317   317.230  2019-01-02
# 8       318   318.100  2019-01-02
# 9       318   318.200  2019-01-02
# 10      318   318.400  2019-01-02
# 11      318   318.110  2019-01-02
# 14      319   319.140  2019-01-02
# 15      319   319.150  2019-01-02
# 16      319   319.160  2019-01-02
# 17      319   319.170  2019-01-02
# 18      319   319.180  2019-01-02
# 19      319   319.340  2019-01-02
# 20      320   320.150  2019-01-02
# 21      321   321.100  2019-01-02
# 22      321   321.200  2019-01-02
# 23      321   321.300  2019-01-02
# 24      321   321.600  2019-01-02
# 25      321   321.700  2019-01-02
# 26      321   321.800  2019-01-02
# 27      321   321.900  2019-01-02
# 28      321   321.100  2019-01-02
# 29      321   321.120  2019-01-02
# 30      321   321.130  2019-01-02
# 31      321   321.150  2019-01-02
# 33      321   321.180  2019-01-02
# ...     ...       ...         ...
# 24447  4413  4413.280  2019-05-10
# 24448  4430  4430.239  2019-05-12
# 24449  4430  4430.259  2019-05-12
# 24450  4430  4430.264  2019-05-12
# 24452  4435  4435.330  2019-05-13
# 24453  4435  4435.340  2019-05-13
# 24455  4435  4435.390  2019-05-13
# 24456  4453  4453.100  2019-05-13
# 24457  4453  4453.600  2019-05-13
# 24458  4456  4456.400  2019-05-13
# 24459  4464  4464.252  2019-05-14
# 24460  4469  4469.200  2019-05-14
# 24461  4478  4478.120  2019-05-14
# 24462  4478  4478.130  2019-05-14
# 24463  4478  4478.140  2019-05-14
# 24464  4482  4482.140  2019-05-15
# 24465  4501  4501.500  2019-05-16
# 24466  4529  4529.458  2019-05-17
# 24468  4559  4559.280  2019-05-20
# 24472  4617  4617.200  2019-05-23
# 24474  4643  4643.130  2019-05-26
# 24476  4643  4643.144  2019-05-26
# 24478  4643  4643.207  2019-05-26
# 24481  4656  4656.261  2019-05-28
# 24482  4656  4656.262  2019-05-28
# 24484  4662  4662.800  2019-05-28
# 24485  4664  4664.300  2019-05-28
# 24487  4664  4664.480  2019-05-28
# 24489  4668  4668.388  2019-05-29
# 24490  4668  4668.393  2019-05-29
#
#                                                    title  \
# 0      'Stalinist' Vietnamese cybersecurity law takes...
# 1      'Stalinist' Vietnamese cybersecurity law takes...
# 3      As Hong Kong tightens screws on rebellion, dem...
# 4      As Hong Kong tightens screws on rebellion, dem...
# 5      As Hong Kong tightens screws on rebellion, dem...
# 6      As Hong Kong tightens screws on rebellion, dem...
# 7      Japan's Emperor Akihito draws record numbers f...
# 8      New acting secretary of defense tells Pentagon...
# 9      New acting secretary of defense tells Pentagon...
# 10     New acting secretary of defense tells Pentagon...
# 11     New acting secretary of defense tells Pentagon...
# 14     Trump downplays stock market swings amid growi...
# 15     Trump downplays stock market swings amid growi...
# 16     Trump downplays stock market swings amid growi...
# 17     Trump downplays stock market swings amid growi...
# 18     Trump downplays stock market swings amid growi...
# 19     Trump downplays stock market swings amid growi...
# 20       Trump's wild ride may get bumpier still in 2019
# 21     Xi Jinping warns Taiwan independence is 'a dea...
# 22     Xi Jinping warns Taiwan independence is 'a dea...
# 23     Xi Jinping warns Taiwan independence is 'a dea...
# 24     Xi Jinping warns Taiwan independence is 'a dea...
# 25     Xi Jinping warns Taiwan independence is 'a dea...
# 26     Xi Jinping warns Taiwan independence is 'a dea...
# 27     Xi Jinping warns Taiwan independence is 'a dea...
# 28     Xi Jinping warns Taiwan independence is 'a dea...
# 29     Xi Jinping warns Taiwan independence is 'a dea...
# 30     Xi Jinping warns Taiwan independence is 'a dea...
# 31     Xi Jinping warns Taiwan independence is 'a dea...
# 33     Xi Jinping warns Taiwan independence is 'a dea...
# ...                                                  ...
# 24447  USseizes North Korean ship amid tense moment i...
# 24448            Stepping out of Warren Buffett's shadow
# 24449            Stepping out of Warren Buffett's shadow
# 24450            Stepping out of Warren Buffett's shadow
# 24452  Arms control a top issue at Russia-UStalks Tue...
# 24453  Arms control a top issue at Russia-UStalks Tue...
# 24455  Arms control a top issue at Russia-UStalks Tue...
# 24456  Pompeo’s Sochi summit could help drive ‘wedge’...
# 24457  Pompeo’s Sochi summit could help drive ‘wedge’...
# 24458     Trump meets Hungary's far-right prime minister
# 24459  Cambria CEO says Trump is '100 percent right' ...
# 24460  Jon Summers: With Trump in the White House, we...
# 24461  William Barr targets Russia investigators; Wal...
# 24462  William Barr targets Russia investigators; Wal...
# 24463  William Barr targets Russia investigators; Wal...
# 24464  Fox News Poll: Voters feel good about economy,...
# 24465  China formally arrests 2 Canadians in case lin...
# 24466  Papadopoulos: Intel agents tried to get my wif...
# 24468  Jimmy Carter finds renaissance in 2020 Democra...
# 24472  As nuclear weapons risk escalates, debate grow...
# 24474  Sen. Lindsey Graham on Trump giving the OK to ...
# 24476  Sen. Lindsey Graham on Trump giving the OK to ...
# 24478  Sen. Lindsey Graham on Trump giving the OK to ...
# 24481  Do economic models predict a Trump re-election...
# 24482  Do economic models predict a Trump re-election...
# 24484  President Trump takes aim at 'low IQ individua...
# 24485  Trump versus Biden heats up during Japan trip;...
# 24487  Trump versus Biden heats up during Japan trip;...
# 24489  Karl Rove: We should not get overconfident abo...
# 24490  Karl Rove: We should not get overconfident abo...
#
#                                                  content nation  week     com  \
# 0      He says the law bears striking similarities to...      c     1  0.1531
# 1      It's obviously inspired by the Chinese securit...      c     1  0.6150
# 3      The prosecution of Tai and his co-defendants c...      c     1 -0.8655
# 4      Critics say this could criminalize swathes of ...      c     1 -0.5423
# 5      The protest is often pointed to as an example ...      c     1  0.7096
# 6      In November, two events featuring Chinese diss...      c     1 -0.4215
# 7      Akihito has repeatedly expressed remorse for h...      c     1 -0.7427
# 8      On his first full day on the job, acting Secre...      c     1  0.1280
# 9      While we're focused on ongoing operations acti...      c     1  0.3818
# 10     His decision to urge the Pentagon's leadership...      c     1 -0.5267
# 11     By focusing on China as opposed to operations ...      c     1  0.1280
# 14     An announcement late Wednesday from Apple that...      c     1 -0.5267
# 15     That could increase the pressure on Trump and ...      c     1 -0.6369
# 16     Trump and Chinese President Xi Jinping agreed ...      c     1 -0.4215
# 17     While the Chinese have indicated a willingness...      c     1  0.2732
# 18     But some White House advisers now worry that t...      c     1 -0.5719
# 19     While he acknowledged the market downturn Wedn...      c     1  0.7650
# 20     The first months of the year will involve cruc...      c     1 -0.4588
# 21     Xi Jinping called on Taiwan to reject independ...      c     1  0.5574
# 22     The Chinese President's Wednesday address was ...      c     1 -0.9100
# 23     By contrast, the latest speech -- marking 40 y...      c     1  0.5859
# 24     Taiwan has been de facto independent from main...      c     1 -0.7579
# 25     China's Communist Party has always maintained ...      c     1 -0.1779
# 26     Cross-strait tensions Xi's speech comes a day ...      c     1 -0.4019
# 27     She also urged that Beijing to respect the com...      c     1  0.8720
# 28     Tsai resigned as head of the Democratic Progre...      c     1 -0.8481
# 29     She also pointed to allegations of Chinese inf...      c     1  0.9022
# 30     During his speech, Xi said China had achieved ...      c     1  0.2960
# 31     I am not sure we are going to get a more clear...      c     1  0.2337
# 33     If the CCP is confident it can stop the DPP fr...      c     1  0.5859
# ...                                                  ...    ...   ...     ...
# 24447  At the White House on Thursday, Trump said the...      n    19 -0.2484
# 24448  WALLACE: I want to turn to another big foreign...      n    19 -0.5106
# 24449  They said to me, they would be -- if they were...      n    19  0.1754
# 24450  They have the most leverage over North Korea a...      n    19  0.2960
# 24452  ___ NORTH KOREA Pompeo is coming to Sochi like...      n    19 -0.4404
# 24453  Russia is likely to press the US to provide mo...      n    19  0.4005
# 24455  North Korea has contended that it needs a nucl...      n    19 -0.4019
# 24456  Pompeo will meet with his Russian counterpart ...      n    19  0.2263
# 24457  A source familiar with the planning of Tuesday...      n    19  0.4588
# 24458  Trump didn't hesitate to meet <U+2014> twice n...      n    19 -0.2700
# 24459  And then we were told if we were magnanimously...      n    20  0.8316
# 24460                Will we go to war with North Korea?      n    20 -0.5994
# 24461  Growing tension with North Korea and Iran The ...      n    20 -0.6705
# 24462  North Korea on Tuesday demanded the US returne...      n    20 -0.6249
# 24463  An unnamed North Korea foreign ministry spokes...      n    20 -0.2023
# 24464  On foreign policy, there’s been a 20-point jum...      n    20  0.0772
# 24465  Kovrig is a former Canadian diplomat and exper...      n    20 -0.6249
# 24466  INGRAHAM: Well, they use -- BLACK: That's how ...      n    20  0.2732
# 24468  He’s an outspoken evangelical Christian who cr...      n    20  0.2500
# 24472  ” This Thursday, May 9, 2019, photo provided F...      n    21 -0.2960
# 24474  North Korea fired off some small weapons which...      n    21 -0.5994
# 24476  GRAHAM: I think is trying to give North Korea ...      n    21 -0.2465
# 24478  If he does act, it helps us with North Korea, ...      n    21  0.3818
# 24481  GABBARD: I am, because the situation with Nort...      n    22 -0.1513
# 24482  Every single day that goes by is a day that No...      n    22  0.3182
# 24484  I think it's definitely on the minds of Capito...      n    22  0.0828
# 24485  Trump doubles-down on 'low IQ' attacks on Bide...      n    22 -0.7575
# 24487  SOME PARTING WORDS Watch the Special Report Al...      n    22  0.5859
# 24489  North Korea, we have a naval armada off the Ko...      n    22  0.3612
# 24490  And the toughest economic sanctions in modern ...      n    22 -0.0772
#
#          neg    neu    pos
# 0      0.129  0.714  0.157
# 1      0.000  0.714  0.286
# 3      0.269  0.731  0.000
# 4      0.170  0.830  0.000
# 5      0.072  0.645  0.283
# 6      0.149  0.851  0.000
# 7      0.191  0.809  0.000
# 8      0.000  0.952  0.048
# 9      0.000  0.880  0.120
# 10     0.064  0.936  0.000
# 11     0.000  0.954  0.046
# 14     0.087  0.913  0.000
# 15     0.184  0.760  0.056
# 16     0.195  0.700  0.105
# 17     0.050  0.853  0.096
# 18     0.144  0.803  0.054
# 19     0.029  0.780  0.190
# 20     0.093  0.837  0.069
# 21     0.111  0.679  0.209
# 22     0.265  0.700  0.035
# 23     0.000  0.920  0.080
# 24     0.206  0.794  0.000
# 25     0.094  0.831  0.075
# 26     0.060  0.940  0.000
# 27     0.000  0.632  0.368
# 28     0.248  0.667  0.086
# 29     0.000  0.738  0.262
# 30     0.116  0.720  0.164
# 31     0.073  0.819  0.108
# 33     0.127  0.673  0.200
# ...      ...    ...    ...
# 24447  0.087  0.913  0.000
# 24448  0.095  0.871  0.034
# 24449  0.111  0.783  0.106
# 24450  0.000  0.896  0.104
# 24452  0.091  0.909  0.000
# 24453  0.000  0.891  0.109
# 24455  0.164  0.713  0.124
# 24456  0.095  0.777  0.127
# 24457  0.000  0.929  0.071
# 24458  0.094  0.847  0.059
# 24459  0.000  0.747  0.253
# 24460  0.358  0.642  0.000
# 24461  0.201  0.752  0.047
# 24462  0.164  0.836  0.000
# 24463  0.140  0.739  0.121
# 24464  0.085  0.850  0.065
# 24465  0.163  0.837  0.000
# 24466  0.000  0.896  0.104
# 24468  0.090  0.784  0.127
# 24472  0.084  0.916  0.000
# 24474  0.231  0.725  0.044
# 24476  0.123  0.800  0.076
# 24478  0.000  0.843  0.157
# 24481  0.137  0.863  0.000
# 24482  0.000  0.892  0.108
# 24484  0.072  0.846  0.082
# 24485  0.212  0.695  0.093
# 24487  0.000  0.833  0.167
# 24489  0.000  0.857  0.143
# 24490  0.106  0.894  0.000
#
# [17789 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(figsize=(20, 10))
fig = sns.lineplot(x="week", y="com",
             hue="nation",
             data= fox_df, ax = ax, dashes = False, ci=None)

# %%
sns.set()


# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x="week", y="com", hue="nation",
               truncate=True, height=5, data=fox_df, scatter = False)

# Use more informative axis labels than are provided by default
g.set_axis_labels("week (mm)", "com (mm)")

# %%
f, ax = plt.subplots(figsize=(20,10))
sns.lineplot(x="week", y="com",
             hue="nation",
             data= nyt_df, ax = ax, dashes = False, ci=None)

# %%
sns.set()

# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x="week", y="com", hue="nation",
               truncate=True, height=5, data=nyt_df, scatter = False)

# Use more informative axis labels than are provided by default
g.set_axis_labels("week (mm)", "com (mm)")

# %%
f, ax = plt.subplots(figsize= (20, 10))
sns.lineplot(x="week", y="com",
             hue="nation",
             data= wp_df, ax = ax, dashes = False, ci=None)

# %%
sns.set()

# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x="week", y="com", hue="nation",
               truncate=True, height=5, data=wp_df, scatter = False)

# Use more informative axis labels than are provided by default
g.set_axis_labels("week", "com")

# %%
f, ax = plt.subplots(figsize=(20, 10))
fig = sns.lineplot(x="week", y="com",
             hue= "nation",
             data= cnn_df, ax = ax, dashes = False, ci=None)

# %%
sns.set()

# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x="week", y="com", hue="nation",
               truncate=True, height=5, data=cnn_df, scatter = False)

# Use more informative axis labels than are provided by default
g.set_axis_labels("week", "com")

# %%
f, ax = plt.subplots(figsize= (20, 10))
sns.lineplot(x="week", y="com",
             hue="nation",
             data= wsj_df, ax = ax, dashes = False, ci=None)

# %%
sns.set()

# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x="week", y="com", hue="nation",
               truncate=True, height=5, data=wsj_df, scatter = False)

# Use more informative axis labels than are provided by default
g.set_axis_labels("week (mm)", "com (mm)")

# %% [markdown]
# ## limitation of dictionary based sentiment analysis.
#
# -

# %% [markdown]
# ### Another considers
#
# ##### Deep learning training, word embedding
# - https://gitlab.com/praj88/deepsentiment/tree/master
# - https://towardsdatascience.com/sentiment-analysis-for-text-with-deep-learning-2f0a0c6472b5
# - https://towardsdatascience.com/word-embeddings-for-sentiment-analysis-65f42ea5d26e
# - https://www.kaggle.com/bertcarremans/using-word-embeddings-for-sentiment-analysis
#
# problem: More sentences are needed to fully learn the neural network. If you do not learn enough with a lot of data, you will lose accuracy. If you have enough data, you will try later.
#
# ##### Machine learning - Ngram sentiment analysis with skitlearn and nltk
#
#
# - https://towardsdatascience.com/basic-binary-sentiment-analysis-using-nltk-c94ba17ae386
# - https://towardsdatascience.com/sentiment-analysis-with-python-part-2-4f71e7bde59a
